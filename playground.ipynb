# %%
import sys
sys.path.append('./my-app')

# %%
# load env variables
from dotenv import load_dotenv

load_dotenv(dotenv_path='my-app/.env',override=True)

# Initialize memory
import sqlite3
from langgraph.checkpoint.sqlite import SqliteSaver

conn = sqlite3.connect(":memory:", check_same_thread = False)
memory = SqliteSaver(conn)

# Import agent
from my_agent.agent import graph
from my_agent.utils.state import DeeperKnowledgeSeekerState

# Initialize state
state = DeeperKnowledgeSeekerState(
    profile="Profile info",
    topic_to_research="topic to research?",
    what_is_already_known="What is already known about topic?"
)


# Run graph
result = graph.invoke(state)

# Display results
print("\n🎯 Znalezione tematy do głębszego poznania:")
for topic in result.deeper_knowledge_results:
    print(f"\nTemat: {topic.topic}")
    print(f"Opis: {topic.description}")
    print(f"Dlaczego to ważne: {topic.why_is_it_important}")
    print("\nŹródła:")
    for source in topic.sources:
        print(f"- {source}")

print("\n📝 Podsumowanie:")
print(result.final_result)
# Out:
# 🎯 Starting create_initial_deeper_knowledge_topics node
# Profile: Jestem programistą z 5-letnim doświadczeniem w Python, specjalizuję się w tworzeniu aplikacji webowych i AI
# Topic to research: Jak efektywnie wykorzystać LangChain do budowy agentów AI?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 26
#      18 state = DeeperKnowledgeSeekerState(
#      19     profile="Jestem programistą z 5-letnim doświadczeniem w Python, specjalizuję się w tworzeniu aplikacji webowych i AI",
#      20     topic_to_research="Jak efektywnie wykorzystać LangChain do budowy agentów AI?",
#      21     what_is_already_known="Znam podstawy LangChain, wiem jak tworzyć proste łańcuchy i używać podstawowych modeli. Chcę się dowiedzieć więcej o zaawansowanych technikach."
#      22 )
#      25 # Run graph
# ---> 26 result = graph.invoke(state)
#      28 # Display results
# ...
